# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adam, SGD
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense,Dropout,GlobalAveragePooling2D
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
from PIL import Image

#Escolhendo GPU: no caso de rodar no srv multigpu, escolher 0 ou 1
#Não pareceu funcionar
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

#Reports
from sklearn.metrics import classification_report, confusion_matrix
# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.models import load_model

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
vgg16_model=keras.applications.vgg16.VGG16(weights='imagenet',include_top=False)

# %%
x = vgg16_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation='relu')(x)
x = Dense(1024,activation='relu')(x)
x = Dense(512,activation='relu')(x)
preds = Dense(1,activation='sigmoid')(x)

# %%
model = Model(inputs=vgg16_model.input,output=preds)

# %%
BATCH_SIZE = 32
TRAINING_DIR = '/home/jailsonpereira/paic/dataset_2/treino/'

# %%
data_generator=ImageDataGenerator(preprocessing_function=preprocess_input,validation_split=0.1)

train_generator=data_generator.flow_from_directory(TRAINING_DIR,
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=BATCH_SIZE,
                                                 class_mode='binary',
                                                 shuffle=True,subset='training')

validation_generator=data_generator.flow_from_directory(TRAINING_DIR,
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=BATCH_SIZE,
                                                 class_mode='binary',
                                                 shuffle=True,subset='validation')

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
# Out:
# Found 1080 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=["accuracy"])

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='CNN_Ince_aval_5.0_best_model.h5', #.{epoch:02d}-{val_loss:.2f}
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,verbose=1)
]

# %%
history = model.fit_generator(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=150,
        callbacks=callbacks_list,
        validation_data=validation_generator,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/150
# 33/33 [==============================] - 20s 607ms/step - loss: 7.1655 - acc: 0.4953 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00001: val_loss improved from inf to 8.05905, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 2/150
# 33/33 [==============================] - 19s 577ms/step - loss: 7.9571 - acc: 0.5063 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00002: val_loss improved from 8.05905 to 7.87589, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 3/150
# 33/33 [==============================] - 19s 587ms/step - loss: 8.2216 - acc: 0.4899 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00003: val_loss did not improve from 7.87589
# Epoch 4/150
# 33/33 [==============================] - 20s 608ms/step - loss: 8.0335 - acc: 0.5016 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00004: val_loss did not improve from 7.87589
# Epoch 5/150
# 33/33 [==============================] - 19s 587ms/step - loss: 8.0999 - acc: 0.4975 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00005: val_loss did not improve from 7.87589
# Epoch 6/150
# 33/33 [==============================] - 19s 576ms/step - loss: 8.1152 - acc: 0.4965 - val_loss: 7.5096 - val_acc: 0.5341
#
# Epoch 00006: val_loss improved from 7.87589 to 7.50957, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 7/150
# 33/33 [==============================] - 20s 593ms/step - loss: 7.9836 - acc: 0.5047 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00007: val_loss did not improve from 7.50957
# Epoch 8/150
# 33/33 [==============================] - 19s 566ms/step - loss: 7.8763 - acc: 0.5113 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00008: val_loss did not improve from 7.50957
# Epoch 9/150
# 33/33 [==============================] - 19s 575ms/step - loss: 7.9365 - acc: 0.5076 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00009: val_loss did not improve from 7.50957
# Epoch 10/150
# 33/33 [==============================] - 21s 636ms/step - loss: 8.1964 - acc: 0.4915 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00010: val_loss did not improve from 7.50957
# Epoch 11/150
# 33/33 [==============================] - 19s 573ms/step - loss: 8.1614 - acc: 0.4936 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00011: val_loss did not improve from 7.50957
# Epoch 12/150
# 33/33 [==============================] - 20s 600ms/step - loss: 8.0950 - acc: 0.4978 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00012: val_loss did not improve from 7.50957
# Epoch 13/150
# 33/33 [==============================] - 18s 535ms/step - loss: 7.8862 - acc: 0.5107 - val_loss: 7.5554 - val_acc: 0.5312
#
# Epoch 00013: val_loss did not improve from 7.50957
# Epoch 14/150
# 33/33 [==============================] - 19s 579ms/step - loss: 7.9068 - acc: 0.5094 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00014: val_loss did not improve from 7.50957
# Epoch 15/150
# 33/33 [==============================] - 21s 622ms/step - loss: 8.1915 - acc: 0.4918 - val_loss: 9.5243 - val_acc: 0.4091
#
# Epoch 00015: val_loss did not improve from 7.50957
# Epoch 16/150
# 33/33 [==============================] - 20s 604ms/step - loss: 8.2629 - acc: 0.4874 - val_loss: 6.9601 - val_acc: 0.5682
#
# Epoch 00016: val_loss improved from 7.50957 to 6.96009, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 17/150
# 33/33 [==============================] - 18s 549ms/step - loss: 7.8507 - acc: 0.5129 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00017: val_loss did not improve from 6.96009
# Epoch 18/150
# 33/33 [==============================] - 19s 583ms/step - loss: 8.3289 - acc: 0.4833 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00018: val_loss did not improve from 6.96009
# Epoch 19/150
# 33/33 [==============================] - 20s 615ms/step - loss: 7.9212 - acc: 0.5086 - val_loss: 7.5096 - val_acc: 0.5341
#
# Epoch 00019: val_loss did not improve from 6.96009
# Epoch 20/150
# 33/33 [==============================] - 18s 556ms/step - loss: 8.2517 - acc: 0.4880 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00020: val_loss did not improve from 6.96009
# Epoch 21/150
# 33/33 [==============================] - 20s 616ms/step - loss: 7.8507 - acc: 0.5129 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00021: val_loss did not improve from 6.96009
# Epoch 22/150
# 33/33 [==============================] - 20s 594ms/step - loss: 8.0083 - acc: 0.5031 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00022: val_loss did not improve from 6.96009
# Epoch 23/150
# 33/33 [==============================] - 20s 609ms/step - loss: 7.8552 - acc: 0.5126 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00023: val_loss did not improve from 6.96009
# Epoch 24/150
# 33/33 [==============================] - 18s 541ms/step - loss: 8.5319 - acc: 0.4707 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00024: val_loss did not improve from 6.96009
# Epoch 25/150
# 33/33 [==============================] - 19s 586ms/step - loss: 7.7537 - acc: 0.5189 - val_loss: 8.5627 - val_acc: 0.4688
#
# Epoch 00025: val_loss did not improve from 6.96009
# Epoch 26/150
# 33/33 [==============================] - 21s 632ms/step - loss: 8.1556 - acc: 0.4940 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00026: val_loss did not improve from 6.96009
# Epoch 27/150
# 33/33 [==============================] - 18s 540ms/step - loss: 8.1551 - acc: 0.4940 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00027: val_loss did not improve from 6.96009
# Epoch 28/150
# 33/33 [==============================] - 20s 595ms/step - loss: 8.1655 - acc: 0.4934 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00028: val_loss did not improve from 6.96009
# Epoch 29/150
# 33/33 [==============================] - 18s 559ms/step - loss: 7.9212 - acc: 0.5086 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00029: val_loss did not improve from 6.96009
# Epoch 30/150
# 33/33 [==============================] - 20s 606ms/step - loss: 8.0644 - acc: 0.4997 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00030: val_loss did not improve from 6.96009
# Epoch 31/150
# 33/33 [==============================] - 19s 589ms/step - loss: 8.1147 - acc: 0.4965 - val_loss: 9.3412 - val_acc: 0.4205
#
# Epoch 00031: val_loss did not improve from 6.96009
# Epoch 32/150
# 33/33 [==============================] - 20s 598ms/step - loss: 7.9526 - acc: 0.5066 - val_loss: 7.1432 - val_acc: 0.5568
#
# Epoch 00032: val_loss did not improve from 6.96009
# Epoch 33/150
# 33/33 [==============================] - 20s 599ms/step - loss: 8.1556 - acc: 0.4940 - val_loss: 7.7233 - val_acc: 0.5208
#
# Epoch 00033: val_loss did not improve from 6.96009
# Epoch 34/150
# 33/33 [==============================] - 19s 590ms/step - loss: 8.0029 - acc: 0.5035 - val_loss: 9.5243 - val_acc: 0.4091
#
# Epoch 00034: val_loss did not improve from 6.96009
# Epoch 35/150
# 33/33 [==============================] - 20s 598ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 6.9601 - val_acc: 0.5682
#
# Epoch 00035: val_loss improved from 6.96009 to 6.96009, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 36/150
# 33/33 [==============================] - 19s 563ms/step - loss: 7.9980 - acc: 0.5038 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00036: val_loss did not improve from 6.96009
# Epoch 37/150
# 33/33 [==============================] - 20s 617ms/step - loss: 8.1807 - acc: 0.4925 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00037: val_loss did not improve from 6.96009
# Epoch 38/150
# 33/33 [==============================] - 19s 587ms/step - loss: 8.0186 - acc: 0.5025 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00038: val_loss did not improve from 6.96009
# Epoch 39/150
# 33/33 [==============================] - 20s 596ms/step - loss: 8.0492 - acc: 0.5006 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00039: val_loss did not improve from 6.96009
# Epoch 40/150
# 33/33 [==============================] - 18s 548ms/step - loss: 7.9369 - acc: 0.5076 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00040: val_loss did not improve from 6.96009
# Epoch 41/150
# 33/33 [==============================] - 20s 621ms/step - loss: 8.1803 - acc: 0.4925 - val_loss: 7.5554 - val_acc: 0.5312
#
# Epoch 00041: val_loss did not improve from 6.96009
# Epoch 42/150
# 33/33 [==============================] - 19s 584ms/step - loss: 8.1255 - acc: 0.4959 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00042: val_loss did not improve from 6.96009
# Epoch 43/150
# 33/33 [==============================] - 18s 554ms/step - loss: 7.9926 - acc: 0.5041 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00043: val_loss did not improve from 6.96009
# Epoch 44/150
# 33/33 [==============================] - 20s 605ms/step - loss: 8.0236 - acc: 0.5022 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00044: val_loss did not improve from 6.96009
# Epoch 45/150
# 33/33 [==============================] - 18s 548ms/step - loss: 7.9827 - acc: 0.5047 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00045: val_loss did not improve from 6.96009
# Epoch 46/150
# 33/33 [==============================] - 21s 637ms/step - loss: 8.2324 - acc: 0.4892 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00046: val_loss did not improve from 6.96009
# Epoch 47/150
# 33/33 [==============================] - 19s 578ms/step - loss: 8.1102 - acc: 0.4968 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00047: val_loss did not improve from 6.96009
# Epoch 48/150
# 33/33 [==============================] - 19s 574ms/step - loss: 8.2265 - acc: 0.4896 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00048: val_loss did not improve from 6.96009
# Epoch 49/150
# 33/33 [==============================] - 21s 622ms/step - loss: 7.9984 - acc: 0.5038 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00049: val_loss did not improve from 6.96009
# Epoch 50/150
# 33/33 [==============================] - 18s 531ms/step - loss: 7.6729 - acc: 0.5240 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00050: val_loss did not improve from 6.96009
# Epoch 51/150
# 33/33 [==============================] - 20s 591ms/step - loss: 7.9419 - acc: 0.5073 - val_loss: 6.5938 - val_acc: 0.5909
#
# Epoch 00051: val_loss improved from 6.96009 to 6.59377, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 52/150
# 33/33 [==============================] - 19s 568ms/step - loss: 8.0442 - acc: 0.5009 - val_loss: 9.3412 - val_acc: 0.4205
#
# Epoch 00052: val_loss did not improve from 6.59377
# Epoch 53/150
# 33/33 [==============================] - 20s 608ms/step - loss: 8.5171 - acc: 0.4716 - val_loss: 7.5554 - val_acc: 0.5312
#
# Epoch 00053: val_loss did not improve from 6.59377
# Epoch 54/150
# 33/33 [==============================] - 19s 585ms/step - loss: 7.7789 - acc: 0.5174 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00054: val_loss did not improve from 6.59377
# Epoch 55/150
# 33/33 [==============================] - 19s 581ms/step - loss: 8.0182 - acc: 0.5025 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00055: val_loss did not improve from 6.59377
# Epoch 56/150
# 33/33 [==============================] - 19s 578ms/step - loss: 8.2126 - acc: 0.4905 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00056: val_loss did not improve from 6.59377
# Epoch 57/150
# 33/33 [==============================] - 20s 619ms/step - loss: 8.2422 - acc: 0.4886 - val_loss: 7.7233 - val_acc: 0.5208
#
# Epoch 00057: val_loss did not improve from 6.59377
# Epoch 58/150
# 33/33 [==============================] - 20s 595ms/step - loss: 7.5912 - acc: 0.5290 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00058: val_loss did not improve from 6.59377
# Epoch 59/150
# 33/33 [==============================] - 18s 538ms/step - loss: 8.2472 - acc: 0.4883 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00059: val_loss did not improve from 6.59377
# Epoch 60/150
# 33/33 [==============================] - 19s 581ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00060: val_loss did not improve from 6.59377
# Epoch 61/150
# 33/33 [==============================] - 20s 608ms/step - loss: 8.1762 - acc: 0.4927 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00061: val_loss did not improve from 6.59377
# Epoch 62/150
# 33/33 [==============================] - 21s 624ms/step - loss: 7.9163 - acc: 0.5089 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00062: val_loss did not improve from 6.59377
# Epoch 63/150
# 33/33 [==============================] - 18s 549ms/step - loss: 8.2580 - acc: 0.4877 - val_loss: 7.5096 - val_acc: 0.5341
#
# Epoch 00063: val_loss did not improve from 6.59377
# Epoch 64/150
# 33/33 [==============================] - 19s 571ms/step - loss: 7.9980 - acc: 0.5038 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00064: val_loss did not improve from 6.59377
# Epoch 65/150
# 33/33 [==============================] - 19s 590ms/step - loss: 8.0029 - acc: 0.5035 - val_loss: 8.5627 - val_acc: 0.4688
#
# Epoch 00065: val_loss did not improve from 6.59377
# Epoch 66/150
# 33/33 [==============================] - 19s 582ms/step - loss: 8.1044 - acc: 0.4972 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00066: val_loss did not improve from 6.59377
# Epoch 67/150
# 33/33 [==============================] - 20s 613ms/step - loss: 7.9989 - acc: 0.5037 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00067: val_loss did not improve from 6.59377
# Epoch 68/150
# 33/33 [==============================] - 19s 566ms/step - loss: 8.0339 - acc: 0.5016 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00068: val_loss did not improve from 6.59377
# Epoch 69/150
# 33/33 [==============================] - 20s 605ms/step - loss: 8.0743 - acc: 0.4991 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00069: val_loss did not improve from 6.59377
# Epoch 70/150
# 33/33 [==============================] - 19s 579ms/step - loss: 8.0999 - acc: 0.4975 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00070: val_loss did not improve from 6.59377
# Epoch 71/150
# 33/33 [==============================] - 20s 601ms/step - loss: 7.8911 - acc: 0.5104 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00071: val_loss did not improve from 6.59377
# Epoch 72/150
# 33/33 [==============================] - 19s 576ms/step - loss: 8.1655 - acc: 0.4934 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00072: val_loss did not improve from 6.59377
# Epoch 73/150
# 33/33 [==============================] - 19s 566ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00073: val_loss did not improve from 6.59377
# Epoch 74/150
# 33/33 [==============================] - 19s 591ms/step - loss: 8.0384 - acc: 0.5013 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00074: val_loss did not improve from 6.59377
# Epoch 75/150
# 33/33 [==============================] - 19s 578ms/step - loss: 8.2113 - acc: 0.4906 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00075: val_loss did not improve from 6.59377
# Epoch 76/150
# 33/33 [==============================] - 20s 604ms/step - loss: 7.9724 - acc: 0.5054 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00076: val_loss did not improve from 6.59377
# Epoch 77/150
# 33/33 [==============================] - 19s 588ms/step - loss: 8.0496 - acc: 0.5006 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00077: val_loss did not improve from 6.59377
# Epoch 78/150
# 33/33 [==============================] - 21s 636ms/step - loss: 8.0640 - acc: 0.4997 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00078: val_loss did not improve from 6.59377
# Epoch 79/150
# 33/33 [==============================] - 17s 520ms/step - loss: 8.0748 - acc: 0.4990 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00079: val_loss did not improve from 6.59377
# Epoch 80/150
# 33/33 [==============================] - 21s 629ms/step - loss: 7.8916 - acc: 0.5104 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00080: val_loss did not improve from 6.59377
# Epoch 81/150
# 33/33 [==============================] - 17s 522ms/step - loss: 8.2831 - acc: 0.4861 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00081: val_loss did not improve from 6.59377
# Epoch 82/150
# 33/33 [==============================] - 21s 632ms/step - loss: 7.9374 - acc: 0.5075 - val_loss: 9.8906 - val_acc: 0.3864
#
# Epoch 00082: val_loss did not improve from 6.59377
# Epoch 83/150
# 33/33 [==============================] - 19s 577ms/step - loss: 7.9724 - acc: 0.5054 - val_loss: 6.2274 - val_acc: 0.6136
#
# Epoch 00083: val_loss improved from 6.59377 to 6.22745, saving model to CNN_Ince_aval_5.0_best_model.h5
# Epoch 84/150
# 33/33 [==============================] - 18s 555ms/step - loss: 8.1354 - acc: 0.4953 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00084: val_loss did not improve from 6.22745
# Epoch 85/150
# 33/33 [==============================] - 21s 641ms/step - loss: 8.3334 - acc: 0.4830 - val_loss: 8.3948 - val_acc: 0.4792
#
# Epoch 00085: val_loss did not improve from 6.22745
# Epoch 86/150
# 33/33 [==============================] - 18s 556ms/step - loss: 7.8238 - acc: 0.5146 - val_loss: 6.9601 - val_acc: 0.5682
#
# Epoch 00086: val_loss did not improve from 6.22745
# Epoch 87/150
# 33/33 [==============================] - 20s 597ms/step - loss: 8.3594 - acc: 0.4814 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00087: val_loss did not improve from 6.22745
# Epoch 88/150
# 33/33 [==============================] - 19s 563ms/step - loss: 7.5454 - acc: 0.5319 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00088: val_loss did not improve from 6.22745
# Epoch 89/150
# 33/33 [==============================] - 20s 609ms/step - loss: 8.2378 - acc: 0.4889 - val_loss: 7.8912 - val_acc: 0.5104
#
# Epoch 00089: val_loss did not improve from 6.22745
# Epoch 90/150
# 33/33 [==============================] - 20s 595ms/step - loss: 8.0128 - acc: 0.5029 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00090: val_loss did not improve from 6.22745
# Epoch 91/150
# 33/33 [==============================] - 19s 571ms/step - loss: 8.2072 - acc: 0.4908 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00091: val_loss did not improve from 6.22745
# Epoch 92/150
# 33/33 [==============================] - 19s 573ms/step - loss: 7.9832 - acc: 0.5047 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00092: val_loss did not improve from 6.22745
# Epoch 93/150
# 33/33 [==============================] - 18s 553ms/step - loss: 7.9665 - acc: 0.5057 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00093: val_loss did not improve from 6.22745
# Epoch 94/150
# 33/33 [==============================] - 22s 655ms/step - loss: 8.1053 - acc: 0.4971 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00094: val_loss did not improve from 6.22745
# Epoch 95/150
# 33/33 [==============================] - 20s 598ms/step - loss: 8.1556 - acc: 0.4940 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00095: val_loss did not improve from 6.22745
# Epoch 96/150
# 33/33 [==============================] - 17s 519ms/step - loss: 8.1048 - acc: 0.4972 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00096: val_loss did not improve from 6.22745
# Epoch 97/150
# 33/33 [==============================] - 20s 605ms/step - loss: 8.1251 - acc: 0.4959 - val_loss: 9.2343 - val_acc: 0.4271
#
# Epoch 00097: val_loss did not improve from 6.22745
# Epoch 98/150
# 33/33 [==============================] - 20s 603ms/step - loss: 7.7587 - acc: 0.5186 - val_loss: 6.9601 - val_acc: 0.5682
#
# Epoch 00098: val_loss did not improve from 6.22745
# Epoch 99/150
# 33/33 [==============================] - 19s 581ms/step - loss: 8.1762 - acc: 0.4927 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00099: val_loss did not improve from 6.22745
# Epoch 100/150
# 33/33 [==============================] - 20s 592ms/step - loss: 8.1358 - acc: 0.4952 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00100: val_loss did not improve from 6.22745
# Epoch 101/150
# 33/33 [==============================] - 20s 604ms/step - loss: 7.9773 - acc: 0.5051 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00101: val_loss did not improve from 6.22745
# Epoch 102/150
# 33/33 [==============================] - 19s 580ms/step - loss: 8.0990 - acc: 0.4975 - val_loss: 7.5096 - val_acc: 0.5341
#
# Epoch 00102: val_loss did not improve from 6.22745
# Epoch 103/150
# 33/33 [==============================] - 20s 601ms/step - loss: 8.0743 - acc: 0.4991 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00103: val_loss did not improve from 6.22745
# Epoch 104/150
# 33/33 [==============================] - 19s 578ms/step - loss: 8.0388 - acc: 0.5013 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00104: val_loss did not improve from 6.22745
# Epoch 105/150
# 33/33 [==============================] - 20s 592ms/step - loss: 7.9930 - acc: 0.5041 - val_loss: 7.3875 - val_acc: 0.5417
#
# Epoch 00105: val_loss did not improve from 6.22745
# Epoch 106/150
# 33/33 [==============================] - 20s 595ms/step - loss: 8.1915 - acc: 0.4918 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00106: val_loss did not improve from 6.22745
# Epoch 107/150
# 33/33 [==============================] - 19s 584ms/step - loss: 7.9216 - acc: 0.5085 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00107: val_loss did not improve from 6.22745
# Epoch 108/150
# 33/33 [==============================] - 20s 596ms/step - loss: 8.1655 - acc: 0.4934 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00108: val_loss did not improve from 6.22745
# Epoch 109/150
# 33/33 [==============================] - 19s 566ms/step - loss: 8.0595 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00109: val_loss did not improve from 6.22745
# Epoch 110/150
# 33/33 [==============================] - 20s 618ms/step - loss: 7.8970 - acc: 0.5101 - val_loss: 8.2422 - val_acc: 0.4886
#
# Epoch 00110: val_loss did not improve from 6.22745
# Epoch 111/150
# 33/33 [==============================] - 18s 537ms/step - loss: 8.2014 - acc: 0.4912 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00111: val_loss did not improve from 6.22745
# Epoch 112/150
# 33/33 [==============================] - 21s 628ms/step - loss: 7.9113 - acc: 0.5092 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00112: val_loss did not improve from 6.22745
# Epoch 113/150
# 33/33 [==============================] - 19s 580ms/step - loss: 8.3639 - acc: 0.4811 - val_loss: 8.3948 - val_acc: 0.4792
#
# Epoch 00113: val_loss did not improve from 6.22745
# Epoch 114/150
# 33/33 [==============================] - 19s 574ms/step - loss: 7.9266 - acc: 0.5082 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00114: val_loss did not improve from 6.22745
# Epoch 115/150
# 33/33 [==============================] - 19s 583ms/step - loss: 7.9221 - acc: 0.5085 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00115: val_loss did not improve from 6.22745
# Epoch 116/150
# 33/33 [==============================] - 21s 647ms/step - loss: 8.2728 - acc: 0.4867 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00116: val_loss did not improve from 6.22745
# Epoch 117/150
# 33/33 [==============================] - 18s 558ms/step - loss: 8.1960 - acc: 0.4915 - val_loss: 8.0590 - val_acc: 0.5000
#
# Epoch 00117: val_loss did not improve from 6.22745
# Epoch 118/150
# 33/33 [==============================] - 18s 558ms/step - loss: 7.6724 - acc: 0.5240 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00118: val_loss did not improve from 6.22745
# Epoch 119/150
# 33/33 [==============================] - 20s 595ms/step - loss: 8.1457 - acc: 0.4946 - val_loss: 7.6927 - val_acc: 0.5227
#
# Epoch 00119: val_loss did not improve from 6.22745
# Epoch 120/150
# 33/33 [==============================] - 19s 571ms/step - loss: 8.1152 - acc: 0.4965 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00120: val_loss did not improve from 6.22745
# Epoch 121/150
# 33/33 [==============================] - 19s 579ms/step - loss: 8.0995 - acc: 0.4975 - val_loss: 7.3875 - val_acc: 0.5417
#
# Epoch 00121: val_loss did not improve from 6.22745
# Epoch 122/150
# 33/33 [==============================] - 19s 574ms/step - loss: 7.9630 - acc: 0.5060 - val_loss: 9.1580 - val_acc: 0.4318
#
# Epoch 00122: val_loss did not improve from 6.22745
# Epoch 123/150
# 33/33 [==============================] - 21s 646ms/step - loss: 8.0891 - acc: 0.4981 - val_loss: 8.4254 - val_acc: 0.4773
#
# Epoch 00123: val_loss did not improve from 6.22745
# Epoch 124/150
# 33/33 [==============================] - 18s 556ms/step - loss: 8.0339 - acc: 0.5016 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00124: val_loss did not improve from 6.22745
# Epoch 125/150
# 33/33 [==============================] - 19s 577ms/step - loss: 7.9724 - acc: 0.5054 - val_loss: 7.7233 - val_acc: 0.5208
#
# Epoch 00125: val_loss did not improve from 6.22745
# Epoch 126/150
# 33/33 [==============================] - 19s 579ms/step - loss: 8.2526 - acc: 0.4880 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00126: val_loss did not improve from 6.22745
# Epoch 127/150
# 33/33 [==============================] - 22s 653ms/step - loss: 7.8866 - acc: 0.5107 - val_loss: 8.6085 - val_acc: 0.4659
#
# Epoch 00127: val_loss did not improve from 6.22745
# Epoch 128/150
# 33/33 [==============================] - 19s 575ms/step - loss: 8.2324 - acc: 0.4892 - val_loss: 7.3264 - val_acc: 0.5455
#
# Epoch 00128: val_loss did not improve from 6.22745
# Epoch 129/150
# 33/33 [==============================] - 19s 571ms/step - loss: 7.9369 - acc: 0.5076 - val_loss: 8.5627 - val_acc: 0.4688
# Epoch 00129: val_loss did not improve from 6.22745
# Epoch 130/150
# 33/33 [==============================] - 20s 607ms/step - loss: 8.1201 - acc: 0.4962 - val_loss: 8.7917 - val_acc: 0.4545
#
# Epoch 00130: val_loss did not improve from 6.22745
# Epoch 131/150
# 33/33 [==============================] - 19s 562ms/step - loss: 8.1857 - acc: 0.4921 - val_loss: 6.9601 - val_acc: 0.5682
#
# Epoch 00131: val_loss did not improve from 6.22745
# Epoch 132/150
# 33/33 [==============================] - 19s 561ms/step - loss: 7.8143 - acc: 0.5152 - val_loss: 7.8759 - val_acc: 0.5114
#
# Epoch 00132: val_loss did not improve from 6.22745
# Epoch 133/150
# 33/33 [==============================] - 20s 612ms/step - loss: 8.0384 - acc: 0.5013 - val_loss: 8.2269 - val_acc: 0.4896
#
# Epoch 00133: val_loss did not improve from 6.22745
# Epoch 00133: early stopping

# %%
#Visualização do treino
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %% [markdown]
# # Avaliação

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
test_dir = '../dataset_2/teste'
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        color_mode="rgb",
        shuffle = False,
        class_mode='categorical',
        batch_size=1)

filenames = test_generator.filenames
nb_samples = len(filenames)
# Out:
# Found 400 images belonging to 2 classes.

# %%
predict = model.predict_generator(test_generator,steps = nb_samples)

# %%
y_pred = np.argmax(predict,axis=1)

# %%
len(y_pred)
# Out:
# 400

# %%
print(confusion_matrix(test_generator.classes,y_pred))
# Out:
# [[200   0]
#  [200   0]]

# %%
#!pip install seaborn

# %%
#Confusion MKatrix
import seaborn as sns
classes = 'arco no_arco'.split()
sns.heatmap(confusion_matrix(test_generator.classes,y_pred),annot=True, xticklabels=classes, yticklabels=classes)

# %%
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=classes))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         arco       0.50      1.00      0.67       200
#      no_arco       0.00      0.00      0.00       200
#
#    micro avg       0.50      0.50      0.50       400
#    macro avg       0.25      0.50      0.33       400
# weighted avg       0.25      0.50      0.33       400

# %%
#t_ini = time.time()
#y_pred = model.predict_generator(x_test)
#t_fim = time.time()
print("Total de exemplos: "+ str(len(test_generator)))
#print("Tempo por exemplo: "+str((t_fim - t_ini)/len(x_test)))

#model.predict_generator(test_generator,steps = nb_samples)

score = model.evaluate_generator(test_generator, steps = nb_samples)
print('Loss de Teste:', score[0])
print('Acurácia de Teste:', score[1])
# Out:
# Total de exemplos: 400
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-37551f4e3408> in <module>
#       7 #model.predict_generator(test_generator,steps = nb_samples)
#       8
# ----> 9 score = model.evaluate_generator(test_generator, steps = nb_samples)
#      10 print('Loss de Teste:', score[0])
#      11 print('Acurácia de Teste:', score[1])
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1470             workers=workers,
#    1471             use_multiprocessing=use_multiprocessing,
# -> 1472             verbose=verbose)
#    1473
#    1474     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     344                                  'or (x, y). Found: ' +
#     345                                  str(generator_output))
# --> 346             outs = model.test_on_batch(x, y, sample_weight=sample_weight)
#     347             outs = to_list(outs)
#     348             outs_per_batch.append(outs)
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/engine/training.py in test_on_batch(self, x, y, sample_weight)
#    1248         x, y, sample_weights = self._standardize_user_data(
#    1249             x, y,
# -> 1250             sample_weight=sample_weight)
#    1251         if self._uses_dynamic_learning_phase():
#    1252             ins = x + y + sample_weights + [0.]
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# ~/anaconda3/envs/diebold/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking target: expected dense_4 to have shape (1,) but got array with shape (2,)
